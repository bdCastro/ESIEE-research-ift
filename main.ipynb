# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: ipywidgets==7.7.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (7.7.1)
# Requirement already satisfied: matplotlib==3.7.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (3.7.0)
# Requirement already satisfied: numpy==1.24.2 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.24.2)
# Requirement already satisfied: pandas==1.5.3 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: torch==1.12.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.12.1)
# Requirement already satisfied: torchvision==0.13.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (0.13.1)
# Requirement already satisfied: tqdm==4.64.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (4.64.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets==7.7.1->-r requirements.txt (line 1)) (6.23.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets==7.7.1->-r requirements.txt (line 1)) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from ipywidgets==7.7.1->-r requirements.txt (line 1)) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets==7.7.1->-r requirements.txt (line 1)) (8.14.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from ipywidgets==7.7.1->-r requirements.txt (line 1)) (3.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib==3.7.0->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib==3.7.0->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib==3.7.0->-r requirements.txt (line 2)) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib==3.7.0->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib==3.7.0->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib==3.7.0->-r requirements.txt (line 2)) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib==3.7.0->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib==3.7.0->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas==1.5.3->-r requirements.txt (line 4)) (2023.3)
# Requirement already satisfied: typing-extensions in /home/codespace/.local/lib/python3.10/site-packages (from torch==1.12.1->-r requirements.txt (line 5)) (4.6.3)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from torchvision==0.13.1->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: comm>=0.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements.txt (line 1)) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements.txt (line 1)) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.5.6)
# Requirement already satisfied: psutil in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements.txt (line 1)) (6.3.2)
# Requirement already satisfied: backcall in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: decorator in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.18.2)
# Requirement already satisfied: pickleshare in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (2.15.1)
# Requirement already satisfied: stack-data in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.7.0->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (6.5.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->torchvision==0.13.1->-r requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->torchvision==0.13.1->-r requirements.txt (line 6)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests->torchvision==0.13.1->-r requirements.txt (line 6)) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->torchvision==0.13.1->-r requirements.txt (line 6)) (2023.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/codespace/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements.txt (line 1)) (3.5.3)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: argon2-cffi in /home/codespace/.local/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (21.3.0)
# Requirement already satisfied: nbformat in /home/codespace/.local/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (5.9.0)
# Requirement already satisfied: nbconvert>=5 in /home/codespace/.local/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (7.5.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/codespace/.local/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/codespace/.local/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.17.1)
# Requirement already satisfied: prometheus-client in /home/codespace/.local/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/codespace/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: pure-eval in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /home/codespace/.local/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /home/codespace/.local/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: beautifulsoup4 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: defusedxml in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: fastjsonschema in /home/codespace/.local/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/codespace/.local/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (4.17.3)
# Requirement already satisfied: argon2-cffi-bindings in /home/codespace/.local/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: webencodings in /home/codespace/.local/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.19.3)
# Requirement already satisfied: anyio>=3.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (3.7.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: overrides in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (7.3.1)
# Requirement already satisfied: websocket-client in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: cffi>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: exceptiongroup in /home/codespace/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (6.0)
# Requirement already satisfied: rfc3339-validator in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: fqdn in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (2.3)
# Requirement already satisfied: uri-template in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /home/codespace/.local/lib/python3.10/site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements.txt (line 1)) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from skimage import data, img_as_float
from skimage.transform import resize

import higra as hg

try:
    from utils import * # imshow, locate_resource
except: # we are probably running from the cloud, try to fetch utils functions from URL
    import urllib.request as request; exec(request.urlopen('https://github.com/higra/Higra-Notebooks/raw/master/utils.py').read(), globals())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 import matplotlib.pyplot as plt
# ----> 5 from skimage import data, img_as_float
#       6 from skimage.transform import resize
#       8 import higra as hg
#
# ModuleNotFoundError: No module named 'skimage'
